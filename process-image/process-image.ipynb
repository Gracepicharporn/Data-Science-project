# %% [markdown]
# # Process image

# %%
! pip install opencv-python
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.2.1 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Building1

# %%
import cv2
import os
from PIL import Image
from PIL import Image, ImageOps

# %%
path = '/Users/gracepichar/Documents/GitHub/Data-Science-project/ON/'
files = os.listdir(path)

# %%
files
# Out:
# ['2013-9-8.png',
#  '2012-11-14.png',
#  '2013-10-23.png',
#  '2016-6-23.png',
#  '2016-8-26.png',
#  '2017-1-16.png',
#  '2016-1-16.png',
#  '2012-11-28.png',
#  '2013-7-7.png',
#  '2016-12-29.png',
#  '2016-12-15.png',
#  '2013-11-4.png',
#  '2015-2-28.png',
#  '2013-6-15.png',
#  '2015-5-21.png',
#  '2014-2-28.png',
#  '2014-5-21.png',
#  '2013-5-5.png',
#  '2015-2-14.png',
#  '2013-6-29.png',
#  '2017-1-9.png',
#  '2013-1-20.png',
#  '2014-2-14.png',
#  '2015-12-21.png',
#  '2013-8-10.png',
#  '2014-12-3.png',
#  '2015-4-8.png',
#  '2015-12-3.png',
#  '2013-3-19.png',
#  '2015-7-24.png',
#  '2013-4-10.png',
#  '2013-3-3.png',
#  '2014-7-30.png',
#  '2014-7-24.png',
#  '2015-7-30.png',
#  '2015-10-18.png',
#  '2013-3-25.png',
#  '2015-7-18.png',
#  '2015-10-30.png',
#  '2014-9-21.png',
#  '2016-5-8.png',
#  '2014-7-18.png',
#  '2014-11-13.png',
#  '2015-10-24.png',
#  '2013-3-31.png',
#  '2015-9-21.png',
#  '2017-4-26.png',
#  '2016-4-26.png',
#  '2013-12-26.png',
# ...

# %%
'2015-1-29.png'[-4:] == '.png'
# Out:
# True

# %%
for image_file in files:
    image = cv2.imread(path + image_file)
    resize = cv2.resize(image, (224, 224))
    gray_scale = cv2.cvtColor(resize, cv2.COLOR_BGR2GRAY)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.imwrite('/Users/gracepichar/Documents/GitHub/Data-Science-project/ON-process/'+ image_file, img)

# %%
image = cv2.imread('/Users/gracepichar/Documents/GitHub/Data-Science-project/ON/2013-9-8.png')
resize = cv2.resize(image, (224, 224))
gray_scale = cv2.cvtColor(resize, cv2.COLOR_BGR2GRAY)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('/Users/gracepichar/Documents/GitHub/Data-Science-project/ON-process/'+ image_file, img)

# %%
from PIL import Image 
from PIL import Image, ImageOps
Image.MAX_IMAGE_PIXELS = 1000000000

# %%
for image_file in files:
    if image_file[-4:] == '.png':
        image = Image.open(path + image_file)
        resize = image.resize((224, 224))
        gray_scale = ImageOps.grayscale(resize)
        gray_scale.save('/Users/gracepichar/Documents/GitHub/Data-Science-project/ON-process/'+ image_file)
    else:
        pass

# %% [markdown]
# # Kettle

# %%
path_kettle = '/Users/gracepichar/Documents/GitHub/Data-Science-project/OFF/Kettle/'
files_kettle = os.listdir(path)

# %%
files_kettle
# Out:
# ['2013-9-8.png',
#  '2012-11-14.png',
#  '2013-10-23.png',
#  '2016-6-23.png',
#  '2016-8-26.png',
#  '2017-1-16.png',
#  '2016-1-16.png',
#  '2012-11-28.png',
#  '2013-7-7.png',
#  '2016-12-29.png',
#  '2016-12-15.png',
#  '2013-11-4.png',
#  '2015-2-28.png',
#  '2013-6-15.png',
#  '2015-5-21.png',
#  '2014-2-28.png',
#  '2014-5-21.png',
#  '2013-5-5.png',
#  '2015-2-14.png',
#  '2013-6-29.png',
#  '2017-1-9.png',
#  '2013-1-20.png',
#  '2014-2-14.png',
#  '2015-12-21.png',
#  '2013-8-10.png',
#  '2014-12-3.png',
#  '2015-4-8.png',
#  '2015-12-3.png',
#  '2013-3-19.png',
#  '2015-7-24.png',
#  '2013-4-10.png',
#  '2013-3-3.png',
#  '2014-7-30.png',
#  '2014-7-24.png',
#  '2015-7-30.png',
#  '2015-10-18.png',
#  '2013-3-25.png',
#  '2015-7-18.png',
#  '2015-10-30.png',
#  '2014-9-21.png',
#  '2016-5-8.png',
#  '2014-7-18.png',
#  '2014-11-13.png',
#  '2015-10-24.png',
#  '2013-3-31.png',
#  '2015-9-21.png',
#  '2017-4-26.png',
#  '2016-4-26.png',
#  '2013-12-26.png',
# ...

# %%
for image_file in files_kettle:
    if image_file[-4:] == '.png':
        image = Image.open(path_kettle + image_file)
        resize = image.resize((224, 224))
        gray_scale = ImageOps.grayscale(resize)
        gray_scale.save('/Users/gracepichar/Documents/GitHub/Data-Science-project/OFF-process/OFF_Kettle_reshape/'+ image_file)
    else:
        pass
